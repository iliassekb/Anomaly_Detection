# %% [markdown]
# # 03 – Evaluation & Anomaly Localization
# Compute AUROC, AP, and visualize anomaly heatmaps on test samples.

# %%
import sys
sys.path.insert(0, '..')
# Run: python scripts/evaluate.py --config experiments/configs/default.yaml
