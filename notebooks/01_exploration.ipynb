# %% [markdown]
# # 01 – Data Exploration
# Load and visualize MVTec 3D-AD samples.

# %%
import sys
sys.path.insert(0, '..')
from src.preprocessing.loader import load_point_cloud
from src.preprocessing.normalize import preprocess
from src.visualization.visualize import show_point_cloud

pcd = load_point_cloud('../data/raw/bagel/train/good/000.ply')
pcd = preprocess(pcd)
show_point_cloud(pcd)
