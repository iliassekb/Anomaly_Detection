# %% [markdown]
# # 02 – Model Training
# Train the VAE / AE interactively and monitor loss curves.

# %%
import sys
sys.path.insert(0, '..')
# Run: python scripts/train.py --config experiments/configs/default.yaml
